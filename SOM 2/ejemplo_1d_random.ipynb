# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import math

plt.rcParams['figure.figsize'] = (12.0, 10.0)

N=1500


x=np.random.rand(N,2)

plt.plot(x[:,0],x[:,1],'.')
plt.show()

# %%
#data = np.matrix.transpose(data)

from minisom import MiniSom
### Initialization and training ###

som2 = MiniSom(200,1,2,sigma=6,learning_rate=0.5)

som2.random_weights_init(x)

som2.train_random(x,10000)


#print(som2.weights)
#print(som.weights[:,:,0].reshape(-1))
#print(som.weights[:,:,1].reshape(-1))

plt.plot(x[:,0],x[:,1],'.')
wx =som2.weights[:,:,0].reshape(-1)
wy = som2.weights[:,:,1].reshape(-1)
plt.plot(wx,wy,'o-')
plt.show()
